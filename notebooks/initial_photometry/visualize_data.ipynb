# %%
from astropy.io import fits 
import numpy as np 

from astropy.table import Table

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
hdul = fits.open("https://archive.stsci.edu/pub/hlsp/frontier/abell370/images/hst/v1.0-epoch2/hlsp_frontier_hst_wfc3-30mas_abell370_f160w_v1.0-epoch2_drz.fits")

# %%
data = hdul[0].data
header = hdul[0].header

# %%
header
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                 9600 / Axis length
# NAXIS2  =                13200 / Axis length
# EXTEND  =                    T / File may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# DATE    = '2016-10-24T17:07:31' / Date FITS file was generated
# IRAF-TLM= '2016-10-24T17:13:14' / Time of last modification
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# FILENAME= 'hlsp_frontier_hst_wfc3-30mas_abell370_f160w_v1.0-epoch2_drz.fits'
# CONTINUE  'ci.fits&'
# CONTINUE  '' / name of file
# FILETYPE= 'SCI      '          / type of data found in data file
#
# TELESCOP= 'HST'                / telescope used to acquire data
# ...

# %%
np.mean(data), np.min(data), np.max(data)
# Out:
# (0.0019522975, -952.58746, 1354.8347)

# %%
plt.imshow(data,vmin=0,vmax=2.9534784e-05*90)

# %%
plt.imshow(data[6200:7100, 5300:6400],vmin=0,vmax=2.9534784e-05*4000)

# %%
plt.imshow(data[6000:7000, 2700:4000],vmin=0,vmax=2.9534784e-05*350)

# %%
data[0]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)
