# %%
from astropy.io import fits 
import numpy as np

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
data = fits.getdata("https://archive.stsci.edu/pub/hlsp/frontier/abell370/images/hst/v1.0-epoch2/hlsp_frontier_hst_acs-30mas_abell370-hffpar_f435w_v1.0-epoch2_drz.fits")

# %%
np.mean(data), np.min(data), np.max(data)
# Out:
# (2.9534784e-05, -1.7794025, 26.572655)

# %%
plt.imshow(data,vmin=0,vmax=2.9534784e-05*90)

# %%
plt.imshow(data[3000:4000, 5000:7000],vmin=0,vmax=2.9534784e-05*90)

# %%
plt.imshow(data[6000:7000, 2700:4000],vmin=0,vmax=2.9534784e-05*350)
